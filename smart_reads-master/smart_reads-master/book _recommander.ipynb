# %%
#book recommendation using collabrative filtering
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books= pd.read_csv('data/BX-Books.csv',sep=";",error_bad_lines=False , encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 books= pd.read_csv('data/BX-Books.csv',sep=";",error_bad_lines=False , encoding='latin-1')
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'. Did you mean 'on_bad_lines'?

# %%
books = pd.read_csv('data/BX-Books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')
# Out:
# C:\Users\yasar\AppData\Local\Temp\ipykernel_14200\2921543543.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('data/BX-Books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books=books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
       'Image-URL-L']]

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-L
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
books.rename(columns={
    "Book-Title": "title",
    "Book-Author": "author",
    "Year-Of-Publication":"year",
    "Publisher": "publisher",
    "Image-URL-L":"img_url"},inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                              img_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users= pd.read_csv('data/BX-Users.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings= pd.read_csv('data/BX-Book-Ratings.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
ratings.head(5)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings.rename(columns={
    "User-ID": "user_id",
    "Book-Rating":"rating"
},inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].value_counts()
#how many ratings gives by user
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 69281         1
# 69239         1
# 69241         1
# 69245         1
# 276733        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['user_id'].unique().shape
#total no of users give ratings
# Out:
# (105283,)

# %%
#total no of users give more than ratings for 200 books
x=ratings['user_id'].value_counts()>200

# %%
x[x].shape
# Out:
# (899,)

# %%
y=x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#         33145,  59727,  44296, 155916, 274808, 268622,  73681,  28634, 188951,
#          9856],
#       dtype='int64', name='user_id', length=899)

# %%
ratings[ratings['user_id'].isin(y)]
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
ratings=ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
books.head(2)
# Out:
#          ISBN                title                author  year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher                                            img_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
ratings_with_books=ratings.merge(books,on="ISBN")

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
# 3   277427  0030615321       0
# 4   277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
# 3  1982        Henry Holt &amp; Co
# 4  2002                 Avon Books
#
#                                              img_url
# ...

# %%
ratings_with_books.shape
# Out:
# (487671, 8)

# %%
num_rating=ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
#book rated with how many times with how much rating 
num_rating.rename(columns={ "rating":"num_of_rating"},inplace=True)

# %%
num_rating.head()
# Out:
#                                                title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              2
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Beyond IBM: Leadership Marketing and Finance ...              1
# 4   Clifford Visita El Hospital (Clifford El Gran...              1

# %%
final_rating=ratings_with_books.merge(num_rating, on='title')

# %%
final_rating.head(2)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1                 Vegetarian Times Complete Cookbook         Lucy  Moll  1995
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1      John Wiley &amp; Sons
#
#                                              img_url  num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/0026217457.0...              7

# %%
final_rating.shape
# Out:
# (487671, 9)

# %%
final_rating=final_rating[final_rating['num_of_rating']>=50]

# %%
final_rating.head()
# Out:
#     user_id        ISBN  rating  \
# 0    277427  002542730X      10
# 13   277427  0060930535       0
# 15   277427  0060934417       0
# 18   277427  0061009059       9
# 24   277427  006440188X       0
#
#                                                 title  \
# 0   Politically Correct Bedtime Stories: Modern Ta...
# 13                      The Poisonwood Bible: A Novel
# 15                                 Bel Canto: A Novel
# 18  One for the Money (Stephanie Plum Novels (Pape...
# 24                                  The Secret Garden
#
#                      author  year                  publisher  \
# 0         James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver  1999                  Perennial
# 15             Ann Patchett  2002                  Perennial
# 18          Janet Evanovich  1995                HarperTorch
# 24  Frances Hodgson Burnett  1998               HarperTrophy
#
# ...

# %%
final_rating.sample(10)
# Out:
#         user_id        ISBN  rating                                 title  \
# 240030   138073  0330375253       0                 Bridget Jones's Diary
# 409389   234597  0345391802       0  The Hitchhiker's Guide to the Galaxy
# 380211   221445  0446611867       0                    A Bend in the Road
# 81100     39646  0345447867       0                        The Apprentice
# 19408     11676  042516098X       5                         Hornet's Nest
# 119257    69232  0446356832       0                     The Sands of Time
# 395789   228764  051511992X       7                    That Camden Summer
# 30699     13850  0446527165       0                         Wish You Well
# 449631   251843  0446513067       7                The General's Daughter
# 264920   153662  0515130966       9                               Riptide
#
#                            author  year                 publisher  \
# 240030             Helen Fielding  2001                   Picador
# ...

# %%
final_rating.shape
# Out:
# (61853, 9)

# %%
#by seeing final_rating sample u can see the duplicates by title apperance no we need get rid of it
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.shape
# Out:
# (59850, 9)

# %%
final_rating
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 13       277427  0060930535       0
# 15       277427  0060934417       0
# 18       277427  0061009059       9
# 24       277427  006440188X       0
# ...         ...         ...     ...
# 487505   275970  1400031354       0
# 487506   275970  1400031362       0
# 487579   275970  1573229725       0
# 487618   275970  1586210661       9
# 487619   275970  1586212230       0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 13                          The Poisonwood Bible: A Novel
# 15                                     Bel Canto: A Novel
# 18      One for the Money (Stephanie Plum Novels (Pape...
# 24                                      The Secret Garden
# ...                                                   ...
# 487505  Tears of the Giraffe (No.1 Ladies Detective Ag...
# ...

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse=csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14961 stored elements and shape (742, 888)>

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance,suggestion=model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 67.75691847, 68.05145112, 72.277244  , 75.81556568,
#         76.30203143]])

# %%
suggestion
# Out:
# array([[237, 238, 240, 241, 184, 536]])

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# '4 Blondes'

# %%
books_name=book_pivot.index

# %%
book_pivot.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %%
import pickle
pickle.dump(model. open('artifacts/model.pkl','wb'))
pickle.dump(books_name.open('artifacts/model.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 2
#       1 import pickle
# ----> 2 pickle.dump(model.open('artifacts/model.pkl','wb'))
#       3 pickle.dump(books_name.open('artifacts/model.pkl','wb'))
#
# AttributeError: 'NearestNeighbors' object has no attribute 'open'

# %%
import os
import pickle

# %%
os.makedirs('artifacts', exist_ok=True)

# %%
# Save the NearestNeighbors model
with open('artifacts/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Save the books_name object (could be a list, DataFrame, etc.)
with open('artifacts/books_name.pkl', 'wb') as f:
    pickle.dump(books_name, f)
with open('artifacts/final_rating.pkl', 'wb') as f:
    pickle.dump(final_rating, f)
with open('artifacts/books_pivot.pkl', 'wb') as f:
    pickle.dump(book_pivot, f)

# %%
def recommend_book(book_name):
    book_id=np.where(book_pivot.index==book_name)[0][0]
    distance,suggestion=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)

    for i in range(len(suggestion)):
        books=book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
book_name='A Bend in the Road'
recommend_book(book_name)
# Out:
# A Bend in the Road
# Exclusive
# The Cradle Will Fall
# No Safe Place
# Family Album
# Lake Wobegon days

# %%
book_name="Harry Potter and the Sorcerer's Stone (Book 1)"
recommend_book(book_name)
# Out:
# Harry Potter and the Sorcerer's Stone (Book 1)
# Jacob Have I Loved
# Exclusive
# Table For Two
# A Man in Full
# Tough Cookie
